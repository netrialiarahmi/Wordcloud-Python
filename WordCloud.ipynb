# %% [markdown]
# Import Package

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %% [markdown]
# Open File

# %%
FILE = Path.cwd() / "/cleaning_data_final.csv"

# %% [markdown]
# Read File

# %%
text = open(FILE, mode="r", encoding="utf-8").read()
stopwords = STOPWORDS

# %% [markdown]
# Create and Generate a Wordcloud Image

# %%
wc = WordCloud(background_color="white", stopwords=stopwords, height=600, width=400)
wc.generate(text)

# %% [markdown]
# Display the generated image

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
